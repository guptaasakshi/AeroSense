# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

# Step 1: Load Dataset (यहाँ अपनी CSV file का नाम और path दो)
file_path = 'city_day.csv'  # अपनी file का exact नाम लिखो
df = pd.read_csv(file_path)

# Step 2: Data Overview
print(df.head())
print("\nMissing values per column:")
print(df.isnull().sum())

# Step 3: Handle Missing Values (simple forward fill)
df.fillna(method='ffill', inplace=True)

# Step 4: Convert date/time column if available (अगर है तो)
if 'date' in df.columns:
    df['date'] = pd.to_datetime(df['Date'])

# Step 5: Choose important pollutant feature columns (अपने dataset के हिसाब से बदलो)
dependent_vars = ['PM2.5', 'PM10', 'NO2', 'CO', 'O3']
feature_cols = [col for col in dependent_vars if col in df.columns]

# Step 6: Normalize features
scaler = MinMaxScaler()
df[feature_cols] = scaler.fit_transform(df[feature_cols])

# Step 7: Create AQI Category (अगर AQI column है)
def categorize_aqi(aqi):
    if aqi <= 50:
        return 'Good'
    elif aqi <= 100:
        return 'Moderate'
    elif aqi <= 200:
        return 'Poor'
    else:
        return 'Hazardous'

if 'AQI' in df.columns:
    df['AQI_Category'] = df['AQI'].apply(categorize_aqi)

# Data preview after preprocessing
print(df.head())

# Save preprocessed data as new CSV (optional)
df.to_csv('preprocessed_airquality_data.csv', index=False)
# Out:
#         City        Date  PM2.5  PM10     NO    NO2    NOx  NH3     CO    SO2  \
# 0  Ahmedabad  2015-01-01    NaN   NaN   0.92  18.22  17.15  NaN   0.92  27.64
# 1  Ahmedabad  2015-01-02    NaN   NaN   0.97  15.69  16.46  NaN   0.97  24.55
# 2  Ahmedabad  2015-01-03    NaN   NaN  17.40  19.30  29.70  NaN  17.40  29.07
# 3  Ahmedabad  2015-01-04    NaN   NaN   1.70  18.48  17.97  NaN   1.70  18.59
# 4  Ahmedabad  2015-01-05    NaN   NaN  22.10  21.42  37.76  NaN  22.10  39.33
#
#        O3  Benzene  Toluene  Xylene  AQI AQI_Bucket
# 0  133.36     0.00     0.02    0.00  NaN        NaN
# 1   34.06     3.68     5.50    3.77  NaN        NaN
# 2   30.70     6.80    16.40    2.25  NaN        NaN
# 3   36.08     4.43    10.14    1.00  NaN        NaN
# 4   39.31     7.01    18.89    2.78  NaN        NaN
#
# Missing values per column:
# City              0
# Date              0
# PM2.5          4598
# PM10          11140
# NO             3582
# NO2            3585
# NOx            4185
# ...
